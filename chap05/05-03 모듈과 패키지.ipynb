# %%
import mod1 as m

print(m.safe_sum(1, 2))
# Out:
# 3

# %%
import mod1
# Out:
# 더할 수 있는 값이 아닙니다.
# None
# 5
# 더할 수 있는 값이 아닙니다.
# None

# %%
import mymodules.mod2 as mod2

# %%
a = mod2.Math()
a.solv(2)
# Out:
# 12.566368

# %%
from mymodules.mod2 import PI, Math, sum
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mymodules.mod2 import PI, Math, sum
#
# ModuleNotFoundError: No module named 'mymodules'

# %%
#sys.path.append(모듈을 저장할 디렉토리)
import sys

for path in sys.path:
    print(path)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\python312.zip
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\DLLs
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib
# c:\Users\Admin\AppData\Local\Programs\Python\Python312
#
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages

# %%
sys.path
# Out:
# ['c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\DLLs',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312',
#  '',
#  'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']

# %%
sys.path.append('C:\big21\python_dev\mymodules')
#절대경로를 먼저 등록해놓으라
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_244\1810761779.py:1: SyntaxWarning: invalid escape sequence '\p'
#   sys.path.append('C:\big21\python_dev\mymodules')

# %%
import mod2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import mod2
#
# ModuleNotFoundError: No module named 'mod2'

# %%
import sys
sys.path
# Out:
# ['c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\DLLs',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312',
#  '',
#  'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages']

# %%
sys.path.append(r'C:\big21\python_dev\mymodules')

# %%
import sys
sys.path
# Out:
# ['c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\DLLs',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312',
#  '',
#  'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python312\\site-packages',
#  'c:\\Users\\Admin\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages',
#  'C:\x08ig21\\python_dev\\mymodules',
#  'C:\\big21\\python_dev\\mymodules',
#  'C:\\big21\\python_dev\\mymodules',
#  'C:\\big21\\python_dev\\mymodules']

# %%
import mod2
print(mod2.sum(3,4))
# Out:
# 7

# %%
#목표: echo 모듈안에 있는 echo_test() 실행
#1. import 사용하는 경우
import game.sound.echo
game.sound.echo.echo_test()
# Out:
# echo

# %%
#2. from ~ import module name
from game.sound import echo_test()
echo_test()
# Out:
#   Cell In[1], line 2
#     from game.sound import echo_test()
#                                     ^
# SyntaxError: invalid syntax

# %%
#3. from ~ import function
# 이게 제일 많이 쓰는방식
# from game.sound.echo import echo_test
from game import *
echo_test()
render_test()
# Out:
# sound 초기화
# echo
# render

# %%
try: 
    age = int(input("나이 입력:  "))
    print(age)
except ValueError:
    print("숫자만 입력하세요")
# Out:
# 숫자만 입력하세요

# %%
try: 
    with open("./chap04/data.csv", "r", encoding="utf-8") as f:
        print(f.read())
except FileNotFoundError:
    print("파일이 없습니다")
# Out:
# 파일이 없습니다
